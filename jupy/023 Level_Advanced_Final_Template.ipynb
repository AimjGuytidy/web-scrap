# %% [markdown]
# # Part 1 - Autotrader.com

# %% [markdown]
# #### Step 1 - Imports

# %%
import requests 
import pandas as pd 
import sqlalchemy

# %%
# autotrader- ganz unten auswählen 100 results
# NIMM DIREKT ZWEITE SEITE UND ÄNDERE PARAMS!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# base?allListingType=al
# requirement: used cars in newyork
# total: 1000 results of each site (total:2k results)
# I will grab the request of page 2 - request sometimes does not appear on this first website -we change params

# %% [markdown]
# #### Step 2 - CURL

# %%
# https://curl.trillworks.com/

# %%
import requests

cookies = {
    'ATC_ID': 'bcdcc205-0534-47a5-833a-3b808e925806',
    'pxa_id': 'viog0xKjK3bcd15JpGGycpiq',
    'pixall_cookie_sync': 'false',
    'pxa_at': 'true',
    'abc': 'viog0xKjK3bcd15JpGGycpiq',
    'pixall_abc': 'viog0xKjK3bcd15JpGGycpiq',
    'hideCookieBanner': 'true',
    'DCNAME': 'www-aws.autotrader.com',
    'AMCVS_A9D33BC75245B2650A490D4D^%^40AdobeOrg': '1',
    'exp': 'csFF~cntl',
    'ATC_USER_RADIUS': '25',
    'ATC_USER_ZIP': '10001',
    'ak_bmsc': 'D285C35AF908AE841D549A018B3496A3~000000000000000000000000000000~...',
    'akaalb_at_alb': '1627718750~op=~rv=15~m=~os=~id=999f1f5f108d5eade8d42788c0a744e0',
    'bm_sz': 'E45706EDA1247A1BB72208A2E8D35530~~4277809~4337970',
    'AWSELB': '63D17F8D0A6A31FD1A70DEEAE0035E96AA49FCE54D848F723F6DDFD386F427AEC4FEFA90B405C50B3490D3F7D77D63186541683A59B44E37A6BAC53AC7882F866E571C486E',
    'AWSELBCORS': '63D17F8D0A6A31FD1A70DEEAE0035E96AA49FCE54D848F723F6DDFD386F427AEC4FEFA90B405C50B3490D3F7D77D63186541683A59B44E37A6BAC53AC7882F866E571C486E',
    'bm_mi': 'D0A7B00E13587AC0A2A7DBF0C637135C~',
    'AMCV_A9D33BC75245B2650A490D4D^%^40AdobeOrg': '1075005958^%^7CMCIDTS^%^7C18839^%^7CMCMID^%^7C23263077471030282033726773398056822787^%^7CMCAID^%^7CNONE^%^7CMCOPTOUT-1627724258s^%^7CNONE^%^7CvVersion^%^7C4.4.1',
    'JSESSIONID': '8F0FAA53210DFE9A1CF1BFC55DECD31B',
    'akaalb_pixall_prod': '1627718879~op=ddc_ana_pixall_prod:eng_ana_pixall_prod-us-west-2^|~rv=4~m=eng_ana_pixall_prod-us-west-2:0^|~os=6aafa3aac97a52a58cd06655a170720e~id=24f9a6a87dee2c0353035ff09b2426f3',
    '_abck': '4A35F6D3C291A9C81C1F3CC203AFBF1B~0~...~-1~^|^|-1^|^|~-1',
    'bm_sv': '3F71743ACF19C897F1F66CBC92090953~vE1Ol/IE+N3ntDU1uuTyaj9EfnxL60rqLFdUNBgsI8e4nlKDgSfHnYCys/NJmBHP5veyeleAMO7gSLB4X/9ySqMfh2yWQKrzIw1eq6LWve5yXqJtwB93Q9fg/zSlWvL7K2yV503HFoo6mSkna3ob3NECPRCnn6yC+dBAz2oy8Hc=',
}

headers = {
    'authority': 'www.autotrader.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
    'content-type': 'application/json',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autotrader.com/cars-for-sale/all-cars/new-york-ny-10001?dma=&searchRadius=25&location=&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100',
    'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
}

params = (
    ('allListingType', 'all-cars'),
    ('city', 'New^%^20York'),
    ('state', 'NY'),
    ('zip', '10001'),
    ('location', '^%^5Bobject^%^20Object^%^5D'),
    ('searchRadius', '25'),
    ('marketExtension', 'include'),
    ('isNewSearch', 'false'),
    ('showAccelerateBanner', 'false'),
    ('sortBy', 'relevance'),
    ('numRecords', '100'),
    ('dma', '^%^5Bobject^%^20Object^%^5D'),
    ('channel', 'ATC'),
    ('relevanceConfig', 'default'),
    ('searchByDma', 'false'),
)

response = requests.get('https://www.autotrader.com/rest/searchresults/base', headers=headers, params=params, cookies=cookies)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.autotrader.com/rest/searchresults/base?allListingType=all-cars&city=New^%^20York&state=NY&zip=10001&location=^%^5Bobject^%^20Object^%^5D&searchRadius=25&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&dma=^%^5Bobject^%^20Object^%^5D&channel=ATC&relevanceConfig=default&searchByDma=false', headers=headers, cookies=cookies)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
# double check if you find infos
results_json = response.json()
results_json
# Out:
# {'filters': {'fuelTypeGroup': {'collapsed': False,
#    'label': 'Fuel Type',
#    'name': 'fuelTypeGroup',
#    'options': [{'count': 536, 'label': 'Diesel', 'value': 'DSL'},
#     {'count': 861, 'label': 'Electric', 'value': 'ELE'},
#     {'count': 59102, 'label': 'Gasoline', 'value': 'GSL'},
#     {'count': 1681, 'label': 'Hybrid', 'value': 'HYB'},
#     {'count': 1, 'label': 'Hydrogen', 'value': 'HYD'},
#     {'count': 131, 'label': 'Plug-in Hybrid', 'value': 'PIH'}]},
#   'yearRange': {'collapsed': False,
#    'label': 'Year',
#    'name': 'yearRange',
#    'options': [{'label': 'Any', 'value': '0'},
#     {'label': '2022', 'value': '2022'},
#     {'label': '2021', 'value': '2021'},
#     {'label': '2020', 'value': '2020'},
#     {'label': '2019', 'value': '2019'},
#     {'label': '2018', 'value': '2018'},
#     {'label': '2017', 'value': '2017'},
#     {'label': '2016', 'value': '2016'},
#     {'label': '2015', 'value': '2015'},
#     {'label': '2014', 'value': '2014'},
# ...

# %%
# dictionary = we can work with keys and values
type(results_json)
# Out:
# dict

# %%
len(results_json)
# Out:
# 6

# %% [markdown]
# #### Step 5 - Output Keys

# %%
# keys = "starting point"
results_json.keys()
# Out:
# dict_keys(['filters', 'listings', 'owners', 'pageData', 'requestParams', 'totalResultCount'])

# %% [markdown]
# #### Step 6 - Find your Data Location

# %% [markdown]
# Necessary data
# - brand
# - model
# - mileage
# - year
# - price

# %%
# result items
result_items = results_json['listings']

# %%
# result items length
len(result_items)
# Out:
# 100

# %%
# brand
result_items[0]['make']
# Out:
# 'Subaru'

# %%
# model
result_items[0]['model']
# Out:
# 'Forester'

# %%
# mileage
result_items[0]['specifications']['mileage']['value']
# Out:
# '6,541'

# %%
# year
result_items[0]['year']
# Out:
# 2018

# %%
# price
result_items[0]['pricingDetail']['derived']
# Out:
# '$30,977'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
brand = []
model = []
mileage = []
year = []
price = []


for result in result_items:
    
    # brand
    brand.append(result['make'])
    
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['specifications']['mileage']['value'])
    
    # year
    year.append(result['year'])
    
    # price
    price.append(result['pricingDetail']['derived'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
autotrader_single_page = pd.DataFrame({'Brand': brand, 'Model': model, 'Mileage': mileage, 'Year': year, 'Price': price})
autotrader_single_page
# Out:
#         Brand            Model Mileage  Year    Price
# 0   Chevrolet          Equinox  19,338  2018  $25,143
# 1       MAZDA             CX-5  39,900  2018  $25,348
# 2   Chevrolet         Corvette  12,658  2016  $79,631
# 3       Honda             HR-V  27,151  2018  $18,514
# 4       Honda            Civic   5,717  2020  $21,777
# 5       Honda           Accord  19,008  2019  $25,651
# 6       Honda            Pilot  34,995  2017  $27,873
# 7       MAZDA             CX-5   6,523  2020  $26,995
# 8     Hyundai           Sonata  17,175  2019  $19,995
# 9       Honda            Civic  19,631  2018  $18,188
# 10       Ford           Fusion   1,345  2019  $21,488
# 11     Nissan            Rogue  27,905  2018  $24,888
# 12     Nissan       Pathfinder  28,509  2018  $25,888
# 13        BMW               X5  43,047  2018  $33,680
# 14      Honda            Civic  51,608  2015  $14,500
# 15      Honda             HR-V  27,262  2018  $21,500
# ...

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 10 pages to get 1000 results, start from 0 (erste 100 Einträge) -9 (result 900-1000)

# %%
brand = []
model = []
mileage = []
year = []
price = []


# NIMM DIREKT ZWEITE SEITE UND ÄNDERE PARAMS!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

for i in range(0,1000,100):

    import requests

    cookies = {
        'ATC_ID': 'bcdcc205-0534-47a5-833a-3b808e925806',
        'pxa_id': 'viog0xKjK3bcd15JpGGycpiq',
        'pixall_cookie_sync': 'false',
        'pxa_at': 'true',
        'abc': 'viog0xKjK3bcd15JpGGycpiq',
        'pixall_abc': 'viog0xKjK3bcd15JpGGycpiq',
        'hideCookieBanner': 'true',
        'DCNAME': 'www-aws.autotrader.com',
        'AMCVS_A9D33BC75245B2650A490D4D^%^40AdobeOrg': '1',
        'exp': 'csFF~cntl',
        'ATC_USER_RADIUS': '25',
        'ATC_USER_ZIP': '10001',
        'ak_bmsc': 'D285C35AF908AE841D549A018B3496A3~000000000000000000000000000000~...',
        'akaalb_at_alb': '1627718750~op=~rv=15~m=~os=~id=999f1f5f108d5eade8d42788c0a744e0',
        'bm_sz': 'E45706EDA1247A1BB72208A2E8D35530~~4277809~4337970',
        'AWSELB': '63D17F8D0A6A31FD1A70DEEAE0035E96AA49FCE54D848F723F6DDFD386F427AEC4FEFA90B405C50B3490D3F7D77D63186541683A59B44E37A6BAC53AC7882F866E571C486E',
        'AWSELBCORS': '63D17F8D0A6A31FD1A70DEEAE0035E96AA49FCE54D848F723F6DDFD386F427AEC4FEFA90B405C50B3490D3F7D77D63186541683A59B44E37A6BAC53AC7882F866E571C486E',
        'bm_mi': 'D0A7B00E13587AC0A2A7DBF0C637135C~',
        'AMCV_A9D33BC75245B2650A490D4D^%^40AdobeOrg': '1075005958^%^7CMCIDTS^%^7C18839^%^7CMCMID^%^7C23263077471030282033726773398056822787^%^7CMCAID^%^7CNONE^%^7CMCOPTOUT-1627724258s^%^7CNONE^%^7CvVersion^%^7C4.4.1',
        '_abck': '4A35F6D3C291A9C81C1F3CC203AFBF1B~0~...~-1~^|^|-1^|^|~-1',
        'JSESSIONID': 'zgKy0onB3d-zoBNWC-dYI4P-sxtUxBXDOTDgViF4.b1ebba8e3c9a',
        'akaalb_pixall_prod': '1627719764~op=ddc_ana_pixall_prod:eng_ana_pixall_prod-us-west-2^|~rv=4~m=eng_ana_pixall_prod-us-west-2:0^|~os=6aafa3aac97a52a58cd06655a170720e~id=98be2a205b7190adc3ac2ddce933563b',
        'bm_sv': '3F71743ACF19C897F1F66CBC92090953~vE1Ol/IE+N3ntDU1uuTyaj9EfnxL60rqLFdUNBgsI8e4nlKDgSfHnYCys/NJmBHP5veyeleAMO7gSLB4X/9ySqMfh2yWQKrzIw1eq6LWve4ovwdxytpHqINASLVdNq04McHhwQ/tNdGFuRUUwrkyuAbrIerLFhQw1sxMfqkeoYM=',
    }

    headers = {
        'authority': 'www.autotrader.com',
        'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
        'content-type': 'application/json',
        'accept': '*/*',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.autotrader.com/cars-for-sale/all-cars/new-york-ny-10001?dma=&searchRadius=25&location=&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=100',
        'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
    }

    params = (
        ('allListingType', 'all-cars'),
        ('city', 'New^%^20York'),
        ('state', 'NY'),
        ('zip', '10001'),
        ('location', '^%^5Bobject^%^20Object^%^5D'),
        ('searchRadius', '25'),
        ('marketExtension', 'include'),
        ('isNewSearch', 'false'),
        ('showAccelerateBanner', 'false'),
        ('sortBy', 'relevance'),
        ('numRecords', '100'),
        ('firstRecord', str(i)),
        ('dma', '^%^5Bobject^%^20Object^%^5D'),
        ('channel', 'ATC'),
        ('relevanceConfig', 'default'),
        ('searchByDma', 'false'),
    )

    response = requests.get('https://www.autotrader.com/rest/searchresults/base', headers=headers, params=params, cookies=cookies)

    #NB. Original query string below. It seems impossible to parse and
    #reproduce query strings 100% accurately so the one below is given
    #in case the reproduced version is not "correct".
    # response = requests.get('https://www.autotrader.com/rest/searchresults/base?allListingType=all-cars&city=New^%^20York&state=NY&zip=10001&location=^%^5Bobject^%^20Object^%^5D&searchRadius=25&marketExtension=include&isNewSearch=false&showAccelerateBanner=false&sortBy=relevance&numRecords=100&firstRecord=100&dma=^%^5Bobject^%^20Object^%^5D&channel=ATC&relevanceConfig=default&searchByDma=false', headers=headers, cookies=cookies)


    response = requests.get('https://www.autotrader.com/rest/searchresults/base', headers=headers, params=params, cookies=cookies)
    
    results_json = response.json()
    
    # result items
    result_items = results_json['listings']
    
    for j in range(len(result_items)):
    
        # brand
        brand.append(result_items[j]['make'])

        # model
        model.append(result_items[j]['model'])

        # mileage
        mileage.append(result_items[j]['specifications']['mileage']['value'])

        # year
        year.append(result_items[j]['year'])

        # price
        price.append(result_items[j]['pricingDetail']['derived'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-6-7e366ba3cd5f> in <module>
#      81     response = requests.get('https://www.autotrader.com/rest/searchresults/base', headers=headers, params=params, cookies=cookies)
#      82
# ---> 83     results_json = response.json()
#      84
#      85     # result items
#
# c:\users\schlee\appdata\local\programs\python\python39\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# c:\users\schlee\appdata\local\programs\python\python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
# ...

# %%
autotrader_multiple_pages = pd.DataFrame({'Brand': brand, 'Model': model, 'Mileage': mileage, 'Year': year, 'Price': price
                                         })
autotrader_multiple_pages
# Out:
#           Brand            Model Mileage  Year    Price
# 0        Subaru         Forester   6,541  2020  $30,977
# 1    Land Rover  Discovery Sport  24,744  2017  $27,051
# 2          Ford         Explorer  33,311  2017  $32,495
# 3         Acura              RDX   9,551  2019  $36,500
# 4         Honda             CR-V  59,101  2012  $14,588
# ..          ...              ...     ...   ...      ...
# 995      Toyota             RAV4  15,305  2019  $28,933
# 996      Toyota           Sienna  28,031  2018  $31,435
# 997      Toyota       Highlander  26,855  2018  $32,669
# 998      Toyota           Tundra   8,635  2020  $51,818
# 999        Audi               Q5  26,448  2018  $32,989
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### Optional (Step 10 - Store Results in Excel)

# %%
# autotrader_multiple_pages.to_excel('autotrader_multiple_pages.xlsx', index=False)

# %% [markdown]
# # Part 2 - Truecar.com

# %% [markdown]
# #### Step 1 - Imports

# %%
# not necessary here (already done)

# %% [markdown]
# #### Step 2 - CURL

# %%
# https://curl.trillworks.com/

# %%
import requests

headers = {
    'authority': 'www.truecar.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
    'accept': 'application/json, text/plain, */*',
    'x-xsrf-token': 'u+alm0FcBq/fOT99a/KJnjm6i2JEYcyWzswn5PZPQvxFsWpNCh7KZFcoraNLinXJRR4JMgsTd6b6Nd3H2u9YKQ==',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/?page=1',
    'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
    'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; g_state=^{^\\^i_p^\\^:1625821812496,^\\^i_l^\\^:1^}; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=-eA9pxCplymILES5R4J2Oo9otmOje2QSKUdxzAOueu8; referrer=ZTC0000000; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; capselaPreferredPostalCode=10001; XSRF-TOKEN=u^%^2Balm0FcBq^%^2FfOT99a^%^2FKJnjm6i2JEYcyWzswn5PZPQvxFsWpNCh7KZFcoraNLinXJRR4JMgsTd6b6Nd3H2u9YKQ^%^3D^%^3D; _abp_backend_session=Tjltc2t6QWIvZ3M5c25WKzFKWkNHczdwbzB0RFBoSXE0b2wwNVh4NytlVnlaOFZzMm5oeFhmSHFvNG1qczluT241ajZ4aFRUeDFKaHJNczU4MlpHZVFOSUp3OStmbWdVelE5U2FqMUdJc1B2T0lFdXBZb0xWK25Bd3JKN3F4WFlxVDBVTVV2d3M1a0FiMVA4cDdiSTJRPT0tLXBIYVNoZkVZUzdVd2srREJUdHplRUE9PQ^%^3D^%^3D--f78c28db3f6a14f74d3d9004eb5d4e22a8ce030d; _dd_s=rum=0&expire=1627711913204',
    'if-none-match': 'W/^\\^7e8b0308bf3f9c29d4c73841afe6e0f7^\\^',
}

params = (
    ('city', 'new-york'),
    ('collapse', 'true'),
    ('fallback', 'true'),
    ('include_incentives', 'true'),
    ('include_targeted_incentives', 'true'),
    ('new_or_used', 'u'),
    ('per_page', '30'),
    ('postal_code', '10001'),
    ('search_event', 'true'),
    ('sort^/[^/]', 'best_match'),
    ('sponsored', 'true'),
    ('state', 'ny'),
)

response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings?city=new-york&collapse=true&fallback=true&include_incentives=true&include_targeted_incentives=true&new_or_used=u&per_page=30&postal_code=10001&search_event=true&sort^\[^\]=best_match&sponsored=true&state=ny', headers=headers)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
# double check if you find infos
results_json = response.json()
results_json
# Out:
# {'listings': [{'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Gray',
#     'exterior_color_rgb': '363938',
#     'exterior_color': 'Selenite Grey Metallic',
#     'exterior_color_id': 887872,
#     'interior_color': 'Black',
# ...

# %%
# dictionary = we can work with keys and values
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
# keys = "starting point"
results_json.keys()
# Out:
# dict_keys(['listings', 'page', 'per_page', 'total', 'fallback', 'fallback_step', 'refine_parameters', 'display', 'list_price', 'sponsored_listings', 'location'])

# %% [markdown]
# #### Step 6 - Find your Data Location

# %% [markdown]
# Necessary data
# - brand
# - model
# - mileage
# - year
# - price

# %%
result_items = results_json['listings']

# %%
len(result_items)
# Out:
# 30

# %%
type(result_items)
# Out:
# list

# %%
result_items
# Out:
# [{'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Gray',
#    'exterior_color_rgb': '363938',
#    'exterior_color': 'Selenite Grey Metallic',
#    'exterior_color_id': 887872,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
# ...

# %%
# brand
result_items[0]['vehicle']['make']
# Out:
# 'Mercedes-Benz'

# %%
# model
result_items[0]['vehicle']['model']
# Out:
# 'C-Class'

# %%
# mileage
result_items[0]['vehicle']['mileage']
# Out:
# 29641

# %%
# year
result_items[0]['vehicle']['year']
# Out:
# 2018

# %%
# price
result_items[0]['pricing']['total_price']
# Out:
# 29901

# %% [markdown]
# #### Step 7 - Find your Data Location

# %%
brand = []
model = []
mileage = []
year = []
price = []

for result in result_items:
    
    # brand
    brand.append(result['vehicle']['make'])
    
    # model
    model.append(result['vehicle']['model'])
    
    # mileage
    mileage.append(result['vehicle']['mileage'])
    
    # year
    year.append(result['vehicle']['year'])
    
    # price
    price.append(result['pricing']['list_price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
truecar_single_page = pd.DataFrame({'Brand': brand, 'Model': model, 'Mileage': mileage, 'Year': year, 'Price': price
                                   })
truecar_single_page
# Out:
#             Brand           Model  Mileage  Year  Price
# 0   Mercedes-Benz         C-Class    29641  2018  29901
# 1           Lexus              RX    39908  2017  30461
# 2   Mercedes-Benz         C-Class    11939  2018  31901
# 3   Mercedes-Benz         C-Class    13015  2018  31902
# 4   Mercedes-Benz         C-Class     9469  2018  32901
# 5   Mercedes-Benz         C-Class    34843  2018  30901
# 6            Jeep  Grand Cherokee    26553  2018  30425
# 7   Mercedes-Benz             GLE    43595  2018  38901
# 8           Lexus              GX    33197  2018  38938
# 9   Mercedes-Benz         C-Class    13363  2018  32901
# 10  Mercedes-Benz         C-Class    17880  2018  32901
# 11      Chevrolet          Malibu    58065  2020  18197
# 12          Lexus              RX    24647  2018  37726
# 13          Lexus              ES     5441  2018  30758
# 14  Mercedes-Benz             GLE    29557  2018  40901
# 15  Mercedes-Benz             GLE    26078  2018  42901
# ...

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 34 pages to get 1020 results)

# %%
brand = []
model = []
mileage = []
year = []
price = []


for i in range (1,170):

    headers = {
        'authority': 'www.truecar.com',
        'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'XA5rOHFc7toHGhhbtZfjYXYNlCeZpsG3YjZFawDtTAOiWaTuOh4iEY8LioWV7x82CqkWd9bUeodWz79ILE1W1g==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/?page=3',
        'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
        'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; g_state=^{^\\^i_p^\\^:1625821812496,^\\^i_l^\\^:1^}; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=-eA9pxCplymILES5R4J2Oo9otmOje2QSKUdxzAOueu8; referrer=ZTC0000000; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; capselaPreferredPostalCode=10001; XSRF-TOKEN=XA5rOHFc7toHGhhbtZfjYXYNlCeZpsG3YjZFawDtTAOiWaTuOh4iEY8LioWV7x82CqkWd9bUeodWz79ILE1W1g^%^3D^%^3D; _abp_backend_session=VzdKeFFFanAwMnU2WStVenRXUHdIdVZIYWY2dkFpNVMyRUtQWDRlUmFrOXRWUTNNTlRKdFZNZGVxV3NlYkFDbk91aTRueUFKOTNMRmFnQzRxdnBJZ0tBY2J1VmQ3TEVPVUM3ZXo1aGlFdkVWWGJSck1qODVBZk0ycm5wSGVzanA5VHEvTzYxcUJITEZTRXYzbGJ2KzN3PT0tLUYyT0I4a1ZncHc0OXhjNm1SMmFhc2c9PQ^%^3D^%^3D--fb1f943bdeefa100635b6f638592148da5387629; _dd_s=rum=0&expire=1627714635889',
        'if-none-match': 'W/^\\^a3e97f624cc37252264dac3cce503ef8^\\^',
    }

    params = (
        ('city', 'new-york'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '10001'),
        ('search_event', 'true'),
        ('sort^/[^/]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ny'),
    )

    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

    results_json = response.json()
    
    result_items = results_json['listings']
    
    for j in range(len(result_items)):
        
        # brand
        brand.append(result_items[j]['vehicle']['make'])

        # model
        model.append(result_items[j]['vehicle']['model'])

        # mileage
        mileage.append(result_items[j]['vehicle']['mileage'])

        # year
        year.append(result_items[j]['vehicle']['year'])
        
        
        # price
        price.append(result_items[j]['pricing']['list_price'])

# %%
price[0]
# Out:
# 29901

# %%
truecar_multiple_pages = pd.DataFrame({'Brand': brand, 'Model': model, 'Mileage': mileage, 'Year': year, 'Price': price
                                      })
truecar_multiple_pages
# Out:
#               Brand     Model  Mileage  Year    Price
# 0     Mercedes-Benz   C-Class    29641  2018  29901.0
# 1     Mercedes-Benz   C-Class    13015  2018  31902.0
# 2             Lexus        RX    39908  2017  30461.0
# 3     Mercedes-Benz   C-Class     9469  2018  32901.0
# 4     Mercedes-Benz       GLE    43595  2018  38901.0
# ...             ...       ...      ...   ...      ...
# 5065           Jeep  Wrangler    43179  2018  38990.0
# 5066           Jeep  Cherokee    28824  2019  26995.0
# 5067            BMW        X3    33553  2018  31935.0
# 5068          Lexus        GX    30161  2018  40962.0
# 5069           Ford      Edge    34080  2018  26995.0
#
# [5070 rows x 5 columns]

# %% [markdown]
# # Part 3 - Combine Dataframes (Autotrader.com & Truecar.com)

# %% [markdown]
# #### bring data in same format

# %%
# mileage
# price
# price column

# %%
autotrader_multiple_pages
# Out:
#           Brand            Model Mileage  Year    Price
# 0        Subaru         Forester   6,541  2020  $30,977
# 1    Land Rover  Discovery Sport  24,744  2017  $27,051
# 2          Ford         Explorer  33,311  2017  $32,495
# 3         Acura              RDX   9,551  2019  $36,500
# 4         Honda             CR-V  59,101  2012  $14,588
# ..          ...              ...     ...   ...      ...
# 995      Toyota             RAV4  15,305  2019  $28,933
# 996      Toyota           Sienna  28,031  2018  $31,435
# 997      Toyota       Highlander  26,855  2018  $32,669
# 998      Toyota           Tundra   8,635  2020  $51,818
# 999        Audi               Q5  26,448  2018  $32,989
#
# [1000 rows x 5 columns]

# %%
autotrader_multiple_pages['Mileage'] = autotrader_multiple_pages['Mileage'].apply(lambda x: x.replace(',',''))

# %%
autotrader_multiple_pages['Price'] = autotrader_multiple_pages['Price'].apply(lambda x: x.replace('$','').replace(',',''))

# %%
autotrader_multiple_pages
# Out:
#           Brand            Model Mileage  Year  Price
# 0        Subaru         Forester    6541  2020  30977
# 1    Land Rover  Discovery Sport   24744  2017  27051
# 2          Ford         Explorer   33311  2017  32495
# 3         Acura              RDX    9551  2019  36500
# 4         Honda             CR-V   59101  2012  14588
# ..          ...              ...     ...   ...    ...
# 995      Toyota             RAV4   15305  2019  28933
# 996      Toyota           Sienna   28031  2018  31435
# 997      Toyota       Highlander   26855  2018  32669
# 998      Toyota           Tundra    8635  2020  51818
# 999        Audi               Q5   26448  2018  32989
#
# [1000 rows x 5 columns]

# %%
truecar_multiple_pages
# Out:
#               Brand           Model  Mileage  Year    Price
# 0     Mercedes-Benz         C-Class    29641  2018  29901.0
# 1             Lexus              RX    39908  2017  30461.0
# 2     Mercedes-Benz         C-Class    11939  2018  31901.0
# 3     Mercedes-Benz         C-Class    13015  2018  31902.0
# 4     Mercedes-Benz         C-Class     9469  2018  32901.0
# ...             ...             ...      ...   ...      ...
# 1015           Ford        Explorer    83382  2014  14995.0
# 1016         Nissan           Rogue    12951  2018  22888.0
# 1017         Toyota          Tacoma    57243  2018  31481.0
# 1018          Mazda          Mazda6   106746  2015   9950.0
# 1019           Jeep  Grand Cherokee   108451  2015  19995.0
#
# [1020 rows x 5 columns]

# %%
# true car multiple pages = replace ('.0', '')

# %%
truecar_multiple_pages['Price'].apply(lambda x: x.replace('.0', ''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-561-a95d2fa72e1e> in <module>
# ----> 1 truecar_multiple_pages['Price'].apply(lambda x: x.replace('.0', ''))
#
# c:\users\schlee\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4210             else:
#    4211                 values = self.astype(object)._values
# -> 4212                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4213
#    4214         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-561-a95d2fa72e1e> in <lambda>(x)
# ----> 1 truecar_multiple_pages['Price'].apply(lambda x: x.replace('.0', ''))
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
# turn float to string first
truecar_multiple_pages['Price'] = truecar_multiple_pages['Price'].astype(str)

# %%
truecar_multiple_pages['Price'] = truecar_multiple_pages['Price'].apply(lambda x: x.replace('.0', ''))

# %%
truecar_multiple_pages
# Out:
#               Brand           Model  Mileage  Year  Price
# 0     Mercedes-Benz         C-Class    29641  2018  29901
# 1             Lexus              RX    39908  2017  30461
# 2     Mercedes-Benz         C-Class    11939  2018  31901
# 3     Mercedes-Benz         C-Class    13015  2018  31902
# 4     Mercedes-Benz         C-Class     9469  2018  32901
# ...             ...             ...      ...   ...    ...
# 1015           Ford        Explorer    83382  2014  14995
# 1016         Nissan           Rogue    12951  2018  22888
# 1017         Toyota          Tacoma    57243  2018  31481
# 1018          Mazda          Mazda6   106746  2015   9950
# 1019           Jeep  Grand Cherokee   108451  2015  19995
#
# [1020 rows x 5 columns]

# %%
autotrader_multiple_pages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5c1d53669c50> in <module>
# ----> 1 autotrader_multiple_pages
#
# NameError: name 'autotrader_multiple_pages' is not defined

# %% [markdown]
# #### rename column name ('Price' -> 'Price in  $ ')

# %%
truecar_multiple_pages = truecar_multiple_pages.rename(columns= {'Price' : 'Price in $'})

# %%
truecar_multiple_pages
# Out:
#               Brand           Model  Mileage  Year Price in $
# 0     Mercedes-Benz         C-Class    29641  2018      29901
# 1             Lexus              RX    39908  2017      30461
# 2     Mercedes-Benz         C-Class    11939  2018      31901
# 3     Mercedes-Benz         C-Class    13015  2018      31902
# 4     Mercedes-Benz         C-Class     9469  2018      32901
# ...             ...             ...      ...   ...        ...
# 1015           Ford        Explorer    83382  2014      14995
# 1016         Nissan           Rogue    12951  2018      22888
# 1017         Toyota          Tacoma    57243  2018      31481
# 1018          Mazda          Mazda6   106746  2015       9950
# 1019           Jeep  Grand Cherokee   108451  2015      19995
#
# [1020 rows x 5 columns]

# %%
autotrader_multiple_pages = autotrader_multiple_pages.rename(columns= {'Price' : 'Price in $'})

# %%
autotrader_multiple_pages
# Out:
#           Brand            Model Mileage  Year Price in $
# 0        Subaru         Forester    6541  2020      30977
# 1    Land Rover  Discovery Sport   24744  2017      27051
# 2          Ford         Explorer   33311  2017      32495
# 3         Acura              RDX    9551  2019      36500
# 4         Honda             CR-V   59101  2012      14588
# ..          ...              ...     ...   ...        ...
# 995      Toyota             RAV4   15305  2019      28933
# 996      Toyota           Sienna   28031  2018      31435
# 997      Toyota       Highlander   26855  2018      32669
# 998      Toyota           Tundra    8635  2020      51818
# 999        Audi               Q5   26448  2018      32989
#
# [1000 rows x 5 columns]

# %%
# merge dataframes

dataframes_merged=pd.concat([truecar_multiple_pages, autotrader_multiple_pages], ignore_index=True)

# %%
dataframes_merged
# Out:
#               Brand       Model Mileage  Year Price in $
# 0     Mercedes-Benz     C-Class   29641  2018      29901
# 1             Lexus          RX   39908  2017      30461
# 2     Mercedes-Benz     C-Class   11939  2018      31901
# 3     Mercedes-Benz     C-Class   13015  2018      31902
# 4     Mercedes-Benz     C-Class    9469  2018      32901
# ...             ...         ...     ...   ...        ...
# 2015         Toyota        RAV4   15305  2019      28933
# 2016         Toyota      Sienna   28031  2018      31435
# 2017         Toyota  Highlander   26855  2018      32669
# 2018         Toyota      Tundra    8635  2020      51818
# 2019           Audi          Q5   26448  2018      32989
#
# [2020 rows x 5 columns]

# %% [markdown]
# ## Connect to Database - PostgreSQL

# %%
# pip install sqlalchemy
# pip install PyMySQL

# %%
# install postgras on comuputer - pdadmin is UI based Application to run SQL wueries

# %%
# password : "password"

# %%
# create sqlalchemy engine
# engine = sqlalchemy.create_engine('postgresql://postgres:Scaleop7@localhost:5432')
